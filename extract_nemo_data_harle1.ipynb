# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
"""
Created on Mon Oct 12 19:59:38 2020
@author: jdha
"""

from netCDF4 import Dataset
import numpy as np


def nc_subset(root_url, root_fname, lon_lim, lat_lim):

    """
    You could also attempt this using NCO but it would require DAP 
    dependance to work
    --> Jelena: it seems that dependencies originate in different package and python versions
    
    example usage:
    
        root_url='http://opendap4gws.jasmin.ac.uk/thredds/nemo/dodsC/grid_T/2005/'
        root_fname='ORCA0083-N06_20050105d05T.nc'
        nc_subset(root_url, root_fname, (0,70), (65,80))
    """
    
    # Lets just set the output filename to the input filename for now
    file_out = 'D:/Barents_Run_Data/ORCA0083-N006/'+root_fname
    file_in  = root_url+'/'+root_fname

    #Jelena: concat the names of the input file. By doing this smartly, the root-fname could be looped and a importation year by year should be possible
    
    # create output file
    # Jelena: the output file is again a netcdf4 file. it keeps the same name.
    ncfile = Dataset(file_out, 'w', format="NETCDF4")
    print(ncfile)
    
    # open input file
    rootgrp = Dataset(file_in, "r")
    
    # grab variable list
    variables  = rootgrp.variables
    dimensions = rootgrp.dimensions
    
    nav_lat = variables['nav_lat'][:,:]
    nav_lon = variables['nav_lon'][:,:]
    
    # sub set lengths
    ind = np.where((nav_lat>=lat_lim[0]) & (nav_lat<=lat_lim[1]) & 
                   (nav_lon >=lon_lim[0]) & (nav_lon<=lon_lim[1]) )
    
    i_coords = (np.min(ind[1]),np.max(ind[1]))
    j_coords = (np.min(ind[0]),np.max(ind[0]))
    
    
    nx = i_coords[1] - i_coords[0] + 1
    ny = j_coords[1] - j_coords[0] + 1
           
    # create the x, y and other dimensions in the outout file
    dim_len={}
    for d in dimensions.keys():
        if d == 'x':
            ncfile.createDimension('x', nx)
            dim_len['x'] = nx
        elif d == 'y':
            ncfile.createDimension('y',ny)
            dim_len['y'] = ny
        else:
            ncfile.createDimension(d, dimensions[d].size)
            dim_len[d] = dimensions[d].size

    # create variables for output
    for v in variables.keys():
        print(v)
        new_var = ncfile.createVariable(v, 
                                        variables[v].dtype.str[1:], 
                                        variables[v].dimensions)
        var_dim_out = []
        var_dim_in  = []
    
        for dim in variables[v].dimensions:
            if dim == 'x':
                var_dim_in.append(slice(i_coords[0],i_coords[1]+1))
                var_dim_out.append(slice(0,nx))
            elif dim =='y':
                var_dim_in.append(slice(j_coords[0],j_coords[1]+1))
                var_dim_out.append(slice(0,ny))
            else:
                if dim_len[dim]>0:
                    var_dim_in.append(slice(0, dim_len[dim]))
                    var_dim_out.append(slice(0, dim_len[dim]))
                else:
                    var_dim_in.append(0)
                    var_dim_out.append(0)
        print(var_dim_out)
        print(var_dim_in)
        # Not too sure why this fix has to be used
        if (var_dim_in[0]==0 and len(var_dim_in)==1):
            var_dim_in=(0,)
            
        # Subset data
        new_var[var_dim_out] = rootgrp.variables[v][var_dim_in]
        
    # close files       
    ncfile.close()
    try: # for some reason I can't close the pointer to the remote data!!
        rootgrp.close() 
    except:
        print('remote file not closed')

# %%
root_url='http://opendap4gws.jasmin.ac.uk/thredds/nemo/dodsC/medusa_d05_grid_U/2010'

#input
month_length = [31,28,31,30,31,30,31,31,30,31,30,31]
year = '2010'
grid = 'd05U'
root_fname1 = 'ORCA0083-N06_'
ftype = '.nc'

m = 1
d = 1
for m in range(11,13):
    if m<10: 
        month = '0'+str(m)             #month counter into file name format
    else: month = str(m)
    while d<=month_length[m-1]:         #length of the concerned month     
        if d<10:                      #nomenclature
            day = '0'+str(d)
        else: day = str(d)
        
        #the file download happens before d is incremented by 5
        root_fname2 = year + month + day + grid
        root_fname = root_fname1 + root_fname2 + ftype

        nc_subset(root_url, root_fname, (0,70), (65,80))
        print(root_fname)
        #after the download: increment of 5 and eventually increment of the month
        d += 5                        #increment of 5 days: here we continue in the while loop, or we exit it
        
    #we exited the while loop if d>month_length of the considered month
    d = month_length[m-1]-(d-5)         #remaining days
    d_control = d
    d = 5-d
    m +=1                             #increment of 1 month
    
#we exit the loop as soon as m==13
#we exit the while loop and in a year where N=365, the remaining days: d==0, otherwise error
if d_control==0:
    print('download of year '+year+ ' complete')
else: 
    print('error in the download')
    print(d_control)
# Out:
# <class 'netCDF4._netCDF4.Dataset'>
# root group (NETCDF4 data model, file format HDF5):
#     dimensions(sizes):
#     variables(dimensions):
#     groups:
# nav_lat
# [slice(0, 548, None), slice(0, 587, None)]
# [slice(2494, 3042, None), slice(3265, 3852, None)]
# nav_lon
# [slice(0, 548, None), slice(0, 587, None)]
# [slice(2494, 3042, None), slice(3265, 3852, None)]
# depthu
# [slice(0, 75, None)]
# [slice(0, 75, None)]
# uo
# [slice(0, 1, None), slice(0, 75, None), slice(0, 548, None), slice(0, 587, None)]
# [slice(0, 1, None), slice(0, 75, None), slice(2494, 3042, None), slice(3265, 3852, None)]
# time_centered
# [slice(0, 1, None)]
# [slice(0, 1, None)]
# time_centered_bounds
# [slice(0, 1, None), slice(0, 2, None)]
# [slice(0, 1, None), slice(0, 2, None)]
# time_counter
# [slice(0, 1, None)]
# [slice(0, 1, None)]
# time_counter_bounds
# [slice(0, 1, None), slice(0, 2, None)]
# [slice(0, 1, None), slice(0, 2, None)]
# tauuo
# [slice(0, 1, None), slice(0, 548, None), slice(0, 587, None)]
# [slice(0, 1, None), slice(2494, 3042, None), slice(3265, 3852, None)]
# ORCA0083-N06_20101101d05U.nc
# <class 'netCDF4._netCDF4.Dataset'>
# root group (NETCDF4 data model, file format HDF5):
#     dimensions(sizes):
#     variables(dimensions):
#     groups:
# nav_lat
# [slice(0, 548, None), slice(0, 587, None)]
# [slice(2494, 3042, None), slice(3265, 3852, None)]
# nav_lon
# [slice(0, 548, None), slice(0, 587, None)]
# [slice(2494, 3042, None), slice(3265, 3852, None)]
# depthu
# [slice(0, 75, None)]
# [slice(0, 75, None)]
# uo
# [slice(0, 1, None), slice(0, 75, None), slice(0, 548, None), slice(0, 587, None)]
# [slice(0, 1, None), slice(0, 75, None), slice(2494, 3042, None), slice(3265, 3852, None)]
# time_centered
# [slice(0, 1, None)]
# [slice(0, 1, None)]
# time_centered_bounds
# [slice(0, 1, None), slice(0, 2, None)]
# [slice(0, 1, None), slice(0, 2, None)]
# time_counter
# [slice(0, 1, None)]
# [slice(0, 1, None)]
# time_counter_bounds
# [slice(0, 1, None), slice(0, 2, None)]
# [slice(0, 1, None), slice(0, 2, None)]
# tauuo
# [slice(0, 1, None), slice(0, 548, None), slice(0, 587, None)]
# [slice(0, 1, None), slice(2494, 3042, None), slice(3265, 3852, None)]
# ORCA0083-N06_20101106d05U.nc
# <class 'netCDF4._netCDF4.Dataset'>
# root group (NETCDF4 data model, file format HDF5):
#     dimensions(sizes):
#     variables(dimensions):
#     groups:
# nav_lat
# [slice(0, 548, None), slice(0, 587, None)]
# [slice(2494, 3042, None), slice(3265, 3852, None)]
# nav_lon
# [slice(0, 548, None), slice(0, 587, None)]
# [slice(2494, 3042, None), slice(3265, 3852, None)]
# depthu
# [slice(0, 75, None)]
# [slice(0, 75, None)]
# uo
# [slice(0, 1, None), slice(0, 75, None), slice(0, 548, None), slice(0, 587, None)]
# [slice(0, 1, None), slice(0, 75, None), slice(2494, 3042, None), slice(3265, 3852, None)]
# time_centered
# [slice(0, 1, None)]
# [slice(0, 1, None)]
# time_centered_bounds
# [slice(0, 1, None), slice(0, 2, None)]
# [slice(0, 1, None), slice(0, 2, None)]
# time_counter
# [slice(0, 1, None)]
# [slice(0, 1, None)]
# time_counter_bounds
# [slice(0, 1, None), slice(0, 2, None)]
# [slice(0, 1, None), slice(0, 2, None)]
# tauuo
# [slice(0, 1, None), slice(0, 548, None), slice(0, 587, None)]
# [slice(0, 1, None), slice(2494, 3042, None), slice(3265, 3852, None)]
# ORCA0083-N06_20101111d05U.nc
# <class 'netCDF4._netCDF4.Dataset'>
# root group (NETCDF4 data model, file format HDF5):
#     dimensions(sizes):
#     variables(dimensions):
#     groups:
# nav_lat
# [slice(0, 548, None), slice(0, 587, None)]
# [slice(2494, 3042, None), slice(3265, 3852, None)]
# nav_lon
# [slice(0, 548, None), slice(0, 587, None)]
# [slice(2494, 3042, None), slice(3265, 3852, None)]
# depthu
# [slice(0, 75, None)]
# [slice(0, 75, None)]
# uo
# [slice(0, 1, None), slice(0, 75, None), slice(0, 548, None), slice(0, 587, None)]
# [slice(0, 1, None), slice(0, 75, None), slice(2494, 3042, None), slice(3265, 3852, None)]
# time_centered
# [slice(0, 1, None)]
# [slice(0, 1, None)]
# time_centered_bounds
# [slice(0, 1, None), slice(0, 2, None)]
# [slice(0, 1, None), slice(0, 2, None)]
# time_counter
# [slice(0, 1, None)]
# [slice(0, 1, None)]
# time_counter_bounds
# [slice(0, 1, None), slice(0, 2, None)]
# [slice(0, 1, None), slice(0, 2, None)]
# tauuo
# [slice(0, 1, None), slice(0, 548, None), slice(0, 587, None)]
# [slice(0, 1, None), slice(2494, 3042, None), slice(3265, 3852, None)]
# ORCA0083-N06_20101116d05U.nc
# <class 'netCDF4._netCDF4.Dataset'>
# root group (NETCDF4 data model, file format HDF5):
#     dimensions(sizes):
#     variables(dimensions):
#     groups:
# nav_lat
# [slice(0, 548, None), slice(0, 587, None)]
# [slice(2494, 3042, None), slice(3265, 3852, None)]
# nav_lon
# [slice(0, 548, None), slice(0, 587, None)]
# [slice(2494, 3042, None), slice(3265, 3852, None)]
# depthu
# [slice(0, 75, None)]
# [slice(0, 75, None)]
# uo
# [slice(0, 1, None), slice(0, 75, None), slice(0, 548, None), slice(0, 587, None)]
# [slice(0, 1, None), slice(0, 75, None), slice(2494, 3042, None), slice(3265, 3852, None)]
# time_centered
# [slice(0, 1, None)]
# [slice(0, 1, None)]
# time_centered_bounds
# [slice(0, 1, None), slice(0, 2, None)]
# [slice(0, 1, None), slice(0, 2, None)]
# time_counter
# [slice(0, 1, None)]
# [slice(0, 1, None)]
# time_counter_bounds
# [slice(0, 1, None), slice(0, 2, None)]
# [slice(0, 1, None), slice(0, 2, None)]
# tauuo
# [slice(0, 1, None), slice(0, 548, None), slice(0, 587, None)]
# [slice(0, 1, None), slice(2494, 3042, None), slice(3265, 3852, None)]
# ORCA0083-N06_20101121d05U.nc
# <class 'netCDF4._netCDF4.Dataset'>
# root group (NETCDF4 data model, file format HDF5):
#     dimensions(sizes):
#     variables(dimensions):
#     groups:
# nav_lat
# [slice(0, 548, None), slice(0, 587, None)]
# [slice(2494, 3042, None), slice(3265, 3852, None)]
# nav_lon
# [slice(0, 548, None), slice(0, 587, None)]
# [slice(2494, 3042, None), slice(3265, 3852, None)]
# depthu
# [slice(0, 75, None)]
# [slice(0, 75, None)]
# uo
# [slice(0, 1, None), slice(0, 75, None), slice(0, 548, None), slice(0, 587, None)]
# [slice(0, 1, None), slice(0, 75, None), slice(2494, 3042, None), slice(3265, 3852, None)]
# time_centered
# [slice(0, 1, None)]
# [slice(0, 1, None)]
# time_centered_bounds
# [slice(0, 1, None), slice(0, 2, None)]
# [slice(0, 1, None), slice(0, 2, None)]
# time_counter
# [slice(0, 1, None)]
# [slice(0, 1, None)]
# time_counter_bounds
# [slice(0, 1, None), slice(0, 2, None)]
# [slice(0, 1, None), slice(0, 2, None)]
# tauuo
# [slice(0, 1, None), slice(0, 548, None), slice(0, 587, None)]
# [slice(0, 1, None), slice(2494, 3042, None), slice(3265, 3852, None)]
# ORCA0083-N06_20101126d05U.nc
# <class 'netCDF4._netCDF4.Dataset'>
# root group (NETCDF4 data model, file format HDF5):
#     dimensions(sizes):
#     variables(dimensions):
#     groups:
# nav_lat
# [slice(0, 548, None), slice(0, 587, None)]
# [slice(2494, 3042, None), slice(3265, 3852, None)]
# nav_lon
# [slice(0, 548, None), slice(0, 587, None)]
# [slice(2494, 3042, None), slice(3265, 3852, None)]
# depthu
# [slice(0, 75, None)]
# [slice(0, 75, None)]
# uo
# [slice(0, 1, None), slice(0, 75, None), slice(0, 548, None), slice(0, 587, None)]
# [slice(0, 1, None), slice(0, 75, None), slice(2494, 3042, None), slice(3265, 3852, None)]
# time_centered
# [slice(0, 1, None)]
# [slice(0, 1, None)]
# time_centered_bounds
# [slice(0, 1, None), slice(0, 2, None)]
# [slice(0, 1, None), slice(0, 2, None)]
# time_counter
# [slice(0, 1, None)]
# [slice(0, 1, None)]
# time_counter_bounds
# [slice(0, 1, None), slice(0, 2, None)]
# [slice(0, 1, None), slice(0, 2, None)]
# tauuo
# [slice(0, 1, None), slice(0, 548, None), slice(0, 587, None)]
# [slice(0, 1, None), slice(2494, 3042, None), slice(3265, 3852, None)]
# ORCA0083-N06_20101201d05U.nc
# <class 'netCDF4._netCDF4.Dataset'>
# root group (NETCDF4 data model, file format HDF5):
#     dimensions(sizes):
#     variables(dimensions):
#     groups:
# nav_lat
# [slice(0, 548, None), slice(0, 587, None)]
# [slice(2494, 3042, None), slice(3265, 3852, None)]
# nav_lon
# [slice(0, 548, None), slice(0, 587, None)]
# [slice(2494, 3042, None), slice(3265, 3852, None)]
# depthu
# [slice(0, 75, None)]
# [slice(0, 75, None)]
# uo
# [slice(0, 1, None), slice(0, 75, None), slice(0, 548, None), slice(0, 587, None)]
# [slice(0, 1, None), slice(0, 75, None), slice(2494, 3042, None), slice(3265, 3852, None)]
# time_centered
# [slice(0, 1, None)]
# [slice(0, 1, None)]
# time_centered_bounds
# [slice(0, 1, None), slice(0, 2, None)]
# [slice(0, 1, None), slice(0, 2, None)]
# time_counter
# [slice(0, 1, None)]
# [slice(0, 1, None)]
# time_counter_bounds
# [slice(0, 1, None), slice(0, 2, None)]
# [slice(0, 1, None), slice(0, 2, None)]
# tauuo
# [slice(0, 1, None), slice(0, 548, None), slice(0, 587, None)]
# [slice(0, 1, None), slice(2494, 3042, None), slice(3265, 3852, None)]
# ORCA0083-N06_20101206d05U.nc
# <class 'netCDF4._netCDF4.Dataset'>
# root group (NETCDF4 data model, file format HDF5):
#     dimensions(sizes):
#     variables(dimensions):
#     groups:
# nav_lat
# [slice(0, 548, None), slice(0, 587, None)]
# [slice(2494, 3042, None), slice(3265, 3852, None)]
# nav_lon
# [slice(0, 548, None), slice(0, 587, None)]
# [slice(2494, 3042, None), slice(3265, 3852, None)]
# depthu
# [slice(0, 75, None)]
# [slice(0, 75, None)]
# uo
# [slice(0, 1, None), slice(0, 75, None), slice(0, 548, None), slice(0, 587, None)]
# [slice(0, 1, None), slice(0, 75, None), slice(2494, 3042, None), slice(3265, 3852, None)]
# time_centered
# [slice(0, 1, None)]
# [slice(0, 1, None)]
# time_centered_bounds
# [slice(0, 1, None), slice(0, 2, None)]
# [slice(0, 1, None), slice(0, 2, None)]
# time_counter
# [slice(0, 1, None)]
# [slice(0, 1, None)]
# time_counter_bounds
# [slice(0, 1, None), slice(0, 2, None)]
# [slice(0, 1, None), slice(0, 2, None)]
# tauuo
# [slice(0, 1, None), slice(0, 548, None), slice(0, 587, None)]
# [slice(0, 1, None), slice(2494, 3042, None), slice(3265, 3852, None)]
# ORCA0083-N06_20101211d05U.nc
# <class 'netCDF4._netCDF4.Dataset'>
# root group (NETCDF4 data model, file format HDF5):
#     dimensions(sizes):
#     variables(dimensions):
#     groups:
# nav_lat
# [slice(0, 548, None), slice(0, 587, None)]
# [slice(2494, 3042, None), slice(3265, 3852, None)]
# nav_lon
# [slice(0, 548, None), slice(0, 587, None)]
# [slice(2494, 3042, None), slice(3265, 3852, None)]
# depthu
# [slice(0, 75, None)]
# [slice(0, 75, None)]
# uo
# [slice(0, 1, None), slice(0, 75, None), slice(0, 548, None), slice(0, 587, None)]
# [slice(0, 1, None), slice(0, 75, None), slice(2494, 3042, None), slice(3265, 3852, None)]
# time_centered
# [slice(0, 1, None)]
# [slice(0, 1, None)]
# time_centered_bounds
# [slice(0, 1, None), slice(0, 2, None)]
# [slice(0, 1, None), slice(0, 2, None)]
# time_counter
# [slice(0, 1, None)]
# [slice(0, 1, None)]
# time_counter_bounds
# [slice(0, 1, None), slice(0, 2, None)]
# [slice(0, 1, None), slice(0, 2, None)]
# tauuo
# [slice(0, 1, None), slice(0, 548, None), slice(0, 587, None)]
# [slice(0, 1, None), slice(2494, 3042, None), slice(3265, 3852, None)]
# ORCA0083-N06_20101216d05U.nc
# <class 'netCDF4._netCDF4.Dataset'>
# root group (NETCDF4 data model, file format HDF5):
#     dimensions(sizes):
#     variables(dimensions):
#     groups:
# nav_lat
# [slice(0, 548, None), slice(0, 587, None)]
# [slice(2494, 3042, None), slice(3265, 3852, None)]
# nav_lon
# [slice(0, 548, None), slice(0, 587, None)]
# [slice(2494, 3042, None), slice(3265, 3852, None)]
# depthu
# [slice(0, 75, None)]
# [slice(0, 75, None)]
# uo
# [slice(0, 1, None), slice(0, 75, None), slice(0, 548, None), slice(0, 587, None)]
# [slice(0, 1, None), slice(0, 75, None), slice(2494, 3042, None), slice(3265, 3852, None)]
# time_centered
# [slice(0, 1, None)]
# [slice(0, 1, None)]
# time_centered_bounds
# [slice(0, 1, None), slice(0, 2, None)]
# [slice(0, 1, None), slice(0, 2, None)]
# time_counter
# [slice(0, 1, None)]
# [slice(0, 1, None)]
# time_counter_bounds
# [slice(0, 1, None), slice(0, 2, None)]
# [slice(0, 1, None), slice(0, 2, None)]
# tauuo
# [slice(0, 1, None), slice(0, 548, None), slice(0, 587, None)]
# [slice(0, 1, None), slice(2494, 3042, None), slice(3265, 3852, None)]
# ORCA0083-N06_20101221d05U.nc
# <class 'netCDF4._netCDF4.Dataset'>
# root group (NETCDF4 data model, file format HDF5):
#     dimensions(sizes):
#     variables(dimensions):
#     groups:
# nav_lat
# [slice(0, 548, None), slice(0, 587, None)]
# [slice(2494, 3042, None), slice(3265, 3852, None)]
# nav_lon
# [slice(0, 548, None), slice(0, 587, None)]
# [slice(2494, 3042, None), slice(3265, 3852, None)]
# depthu
# [slice(0, 75, None)]
# [slice(0, 75, None)]
# uo
# [slice(0, 1, None), slice(0, 75, None), slice(0, 548, None), slice(0, 587, None)]
# [slice(0, 1, None), slice(0, 75, None), slice(2494, 3042, None), slice(3265, 3852, None)]
# time_centered
# [slice(0, 1, None)]
# [slice(0, 1, None)]
# time_centered_bounds
# [slice(0, 1, None), slice(0, 2, None)]
# [slice(0, 1, None), slice(0, 2, None)]
# time_counter
# [slice(0, 1, None)]
# [slice(0, 1, None)]
# time_counter_bounds
# [slice(0, 1, None), slice(0, 2, None)]
# [slice(0, 1, None), slice(0, 2, None)]
# tauuo
# [slice(0, 1, None), slice(0, 548, None), slice(0, 587, None)]
# [slice(0, 1, None), slice(2494, 3042, None), slice(3265, 3852, None)]
# ORCA0083-N06_20101226d05U.nc
# <class 'netCDF4._netCDF4.Dataset'>
# root group (NETCDF4 data model, file format HDF5):
#     dimensions(sizes):
#     variables(dimensions):
#     groups:
# nav_lat
# [slice(0, 548, None), slice(0, 587, None)]
# [slice(2494, 3042, None), slice(3265, 3852, None)]
# nav_lon
# [slice(0, 548, None), slice(0, 587, None)]
# [slice(2494, 3042, None), slice(3265, 3852, None)]
# depthu
# [slice(0, 75, None)]
# [slice(0, 75, None)]
# uo
# [slice(0, 1, None), slice(0, 75, None), slice(0, 548, None), slice(0, 587, None)]
# [slice(0, 1, None), slice(0, 75, None), slice(2494, 3042, None), slice(3265, 3852, None)]
# time_centered
# [slice(0, 1, None)]
# [slice(0, 1, None)]
# time_centered_bounds
# [slice(0, 1, None), slice(0, 2, None)]
# [slice(0, 1, None), slice(0, 2, None)]
# time_counter
# [slice(0, 1, None)]
# [slice(0, 1, None)]
# time_counter_bounds
# [slice(0, 1, None), slice(0, 2, None)]
# [slice(0, 1, None), slice(0, 2, None)]
# tauuo
# [slice(0, 1, None), slice(0, 548, None), slice(0, 587, None)]
# [slice(0, 1, None), slice(2494, 3042, None), slice(3265, 3852, None)]
# ORCA0083-N06_20101231d05U.nc
# download of year 2010 complete
